# %%
# %sql
create catalog if not exists Customer_360;

# %%
# %sql
use catalog Customer_360;

# %%
# %sql
create schema if not exists Customer_360.bronze;
create schema if not exists Customer_360.silver;
create schema if not exists Customer_360.gold;

# %%
# %sql
show databases from Customer_360;

# %%
# %sql
create schema if not exists Customer_360.source_data;

# %%
# %sql
select * from read_files(
   '/Volumes/customer_360/source_data/raw/Accounts/',
   format => 'CSV',
   header => 'true' 
)

# %%
# %sql
select * from read_files(
   '/Volumes/customer_360/source_data/raw/Branches/branches.csv',
   format => 'CSV',
   header => 'true' 
)

# %%
# %sql
select * from read_files(
   '/Volumes/customer_360/source_data/raw/Cards/',
   format => 'CSV',
   header => 'true' 
)

# %%
# %sql
select * from read_files(
   '/Volumes/customer_360/source_data/raw/Customer_Transactions/',
   format => 'CSV',
   header => 'true' 
)
